# %% [markdown]
# # Problem Statement 1: Employee Performance Bonus Eligibility
# Description:
#
# A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.
#
# Requirements:
#
# Identify the highest performance score.
#
# Handle ties if multiple employees have the same highest score.
#
# Display all employees eligible for the top performance bonus.
#
# Input:
#
# employees = {
#
# "Ravi": 92,
#
# "Anita": 88,
#
# "Kiran": 92,
#
# "Suresh": 85
#
# }
#
# Expected Output:
#
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %%
#input
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
max_score = max(employees.values())

# %%
#finding top performers
top_performers = []
for name, score in employees.items():
  if score == max_score:
    top_performers.append(name)

#printing top performers with score
print("Top Performers Eligible for Bonus:", ", ".join(top_performers), f"(Score: {max_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# # Problem Statement 2: Search Query Keyword Analysis
#
# Description:
#
# An e-commerce website stores customer search queries. You are given a search query sentence entered by a user.
#
# Requirements:
#
# Convert the input to lowercase.
#
# Ignore common punctuation.
#
# Count the frequency of each keyword.
#
# Display only keywords searched more than once.
#
# Input:
#
# "Buy mobile phone buy phone online"
#
# Expected Output:
# {'buy': 2, 'phone': 2}

# %%
import string
#input and converting to lopwercase
sentence=input("Enter Search Query Sentence:").lower()
#removing common punctuations and splitting
sentence=sentence.translate(str.maketrans("", "", string.punctuation))
words=sentence.split()
print(sentence)
# Out:
# Enter Search Query Sentence:"Buy mobile phone buy phone online"
# buy mobile phone buy phone online

# %%
#logic
Query_count={}
for word in words:
  if word in Query_count:
    Query_count[word]+=1
  else:
    Query_count[word]=1

# %%
#finding and printing repeated words
print({query: count for query, count in Query_count.items() if count > 1})
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# # Problem Statement 3: Sensor Data Validation
# Description:
#
# A factory collects sensor readings every hour. Each reading is stored in a list where the index represents the hour and the value represents the sensor reading.
#
# Requirements:
#
# Identify readings that are even numbers (valid readings).
#
# Store them as (hour_index, reading_value) pairs.
#
# Ignore odd readings (invalid readings).
#
# Input:
#
# sensor_readings = [3, 4, 7, 8, 10, 12, 5]
#
# Expected Output:
#
# Valid Sensor Readings (Hour, Value):
#
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
#input readings
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
print(sensor_readings)

# %%
#separating even readings from odd and appending their respected hour into a list
valid_readings = []
for i in range(len(sensor_readings)):
  if sensor_readings[i] % 2 == 0:
    valid_readings.append((i, sensor_readings[i]))

# %%
#printing valid readings
print(valid_readings)
# Out:
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# # Problem Statement 4: Email Domain Usage Analysis
# Description:
#
# A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.
#
# Requirements:
#
# Count how many users belong to each email domain.
#
# Calculate the percentage usage of each domain.
#
# Input:
#
# emails = [
# "ravi@gmail.com",
#
# "anita@yahoo.com",
#
# "kiran@gmail.com",
#
# "suresh@gmail.com",
#
# "meena@yahoo.com"
# ]
#
# Expected Output:
#
# gmail.com: 60%
#
# yahoo.com: 40%

# %%
#input
emails = [
"ravi@gmail.com",
"anita@yahoo.com",
"kiran@gmail.com",
"suresh@gmail.com",
"meena@yahoo.com"
]

# %%
from typing import Counter
#storing only domains by splitting mails
domains=[email.split("@")[1] for email in emails]
#counting each domain
domain_counts=Counter(domains)

# %%
#calculating each domain percentage of usage
total_domains=len(emails)
for domain, count in domain_counts.items():
  percentage=(count/total_domains)*100
  print(f"{domain}:{percentage:.0f}%")
# Out:
# gmail.com:60%
# yahoo.com:40%

# %% [markdown]
# # Problem Statement 5: Sales Spike Detection
# Description:
#
# A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.
#
# Requirements:
#
# Calculate the average daily sales.
#
# Detect days where sales are more than 30% above average.
#
# Display the day number and sale value.
#
# Input:
#
# sales = [1200, 1500, 900, 2200, 1400, 3000]
#
# Expected Output:
#
# Day 4: 2200
#
# Day 6: 3000

# %%
#input
sales = [1200, 1500, 900, 2200, 1400, 3000]

# %%
#Avg sales per day
Avg_sales=sum(sales)/len(sales)
threshould=Avg_sales*1.3
#finding the sales above 30% of avg day sales
for day,sale in enumerate(sales):
  if sale>=threshould:
    print(f"Day {day+1}:{sale}")
# Out:
# Day 6:3000

# %% [markdown]
# # Problem Statement 6: Duplicate User ID Detection
# Description:
#
# A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.
#
# Requirements:
#
# Identify duplicate user IDs.
#
# Display how many times each duplicate appears.
#
# Input:
#
# user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
#
# Expected Output:
#
# user1 → 3 times
#
# user3 → 2 times

# %%
#input
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

# %%
#counting duplicate user identities
user_counts=Counter(user_ids)
#finding the duplicate identities with count
for user,count in user_counts.items():
  if count>1:
    print(f"{user} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times

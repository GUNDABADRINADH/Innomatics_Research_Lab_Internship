# %% [markdown]
# # Problem 1: Social Media – Post Engagement Analyzer
# Problem Statement
#
# Create a function to analyze engagement on a social media post.
#
# Rules
#
# Calculate total likes
#
# If Total Likes ≥ 1000 → Viral Post
#
# Otherwise → Normal Engagement
#
# Real-Time Use
#
# Social media analytics platforms
#
# Marketing dashboards
#
# Hint
#
# Use function
#
# Use loop for calculations
#
# Expected Output Format
#
# Total Likes: 1050
#
# Post Status: Viral Post

# %%
#post Engagement Analyzer
def post_engagement_analyzer(id,likes):
  print(f"Total Likes: {likes}")
  if likes >= 1000:
      print(f"Post Status of {id}: Viral Post")
  else:
      print(f"Post Status of {id}: Normal Engagement")

# %%
posts_likes=[100,503,1034,999,134,1676,2345,239,1378,9088]

# %%
for i in range(len(posts_likes)):
  post_engagement_analyzer(i,posts_likes[i])
# Out:
# Total Likes: 100
# Post Status of 0: Normal Engagement
# Total Likes: 503
# Post Status of 1: Normal Engagement
# Total Likes: 1034
# Post Status of 2: Viral Post
# Total Likes: 999
# Post Status of 3: Normal Engagement
# Total Likes: 134
# Post Status of 4: Normal Engagement
# Total Likes: 1676
# Post Status of 5: Viral Post
# Total Likes: 2345
# Post Status of 6: Viral Post
# Total Likes: 239
# Post Status of 7: Normal Engagement
# Total Likes: 1378
# Post Status of 8: Viral Post
# Total Likes: 9088
# Post Status of 9: Viral Post

# %% [markdown]
# # Problem 2: Healthcare – Medicine Stock Alert System
#
# Problem Statement
#
# Create a function to monitor medicine stock levels.
#
# Rules
#
# Stock < 10 → Low Stock Alert
#
# Stock ≥ 10 → Stock Sufficient
#
# Real-Time Use
#
# Pharmacy management systems
#
# Hospital inventory tracking
# Hint
#
# Use function
# Use conditional logic
#
# Expected Output Format
#
# Medicine Stock: 6
#
# Status: Low Stock Alert

# %%
#Function for medicine stock alert system
def medicine_stock_alert(stock):
  print(f"Medicine Stock: {stock}")
  if stock < 10:
    print("Status: Low Stock Alert")
  else:
    print("Status: Stock Sufficient")

# %%
medicine_stock=[2,8,54,61,10,12,5,8,9,16,19]

# %%
for i in medicine_stock:
  medicine_stock_alert(i)
# Out:
# Medicine Stock: 2
# Status: Low Stock Alert
# Medicine Stock: 8
# Status: Low Stock Alert
# Medicine Stock: 54
# Status: Stock Sufficient
# Medicine Stock: 61
# Status: Stock Sufficient
# Medicine Stock: 10
# Status: Stock Sufficient
# Medicine Stock: 12
# Status: Stock Sufficient
# Medicine Stock: 5
# Status: Low Stock Alert
# Medicine Stock: 8
# Status: Low Stock Alert
# Medicine Stock: 9
# Status: Low Stock Alert
# Medicine Stock: 16
# Status: Stock Sufficient
# Medicine Stock: 19
# Status: Stock Sufficient

# %% [markdown]
# # Problem 3: Agriculture – Rainfall Adequacy Checker
# Problem Statement
#
# Create a function that analyzes seasonal rainfall data.
#
# Rules
#
#
# Calculate average rainfall
#
# Average ≥ required level → Adequate Rainfall
#
# Otherwise → Inadequate Rainfall
#
# Real-Time Use
#
# Climate monitoring systems
#
# Irrigation planning tools
#
# Hint
#
# Use function
#
# Use loop and math operations
#
# Expected Output Format
#
# Average Rainfall: 72
#
# Rainfall Status: Adequate Rainfall

# %%
#function to analyze rainfall
def rainfall_analyzer(rainfall_data):
  total_rainfall = sum(rainfall_data)
  average_rainfall = total_rainfall / len(rainfall_data)
  print(f"Average Rainfall: {average_rainfall}")
  if average_rainfall >= 50:
    print("Rainfall Status: Adequate Rainfall")
  else:
    print("Rainfall Status: Inadequate Rainfall")

# %%
Rainfall_data=[34,60,30,70,36,54,73,33,22]
rainfall_analyzer(Rainfall_data)
# Out:
# Average Rainfall: 45.77777777777778
# Rainfall Status: Inadequate Rainfall

# %% [markdown]
# # Problem 4: Social Media – Duplicate Account Detection
# Problem Statement
#
# Create a function to detect duplicate usernames in a system.
#
# Rules
#
# If duplicates exist → Flag accounts
#
# Else → Accounts are unique
#
# Real-Time Use
#
# Platform moderation
#
# Fraud detection systems
#
# Hint
#
# Use function
#
# Use set data structure
#
# Expected Output Format
#
# Duplicate Accounts Found: Yes

# %%
#function to detect duplicate usernames
def detect_duplicate_usernames(usernames):
  unique_usernames = set(usernames)
  if len(usernames) == len(unique_usernames):
    print("Duplicate Accounts Found: No")
  else:
    print("Duplicate Accounts Found: Yes")

# %%
usernames=["Raghu","Rani","Ravi","Sai","Kumar","Rani"]
detect_duplicate_usernames(usernames)
# Out:
# Duplicate Accounts Found: Yes

# %% [markdown]
# # Problem 5: Healthcare – Appointment Eligibility Checker
#
# Problem Statement
#
# Create a function to check whether a patient is eligible for an appointment slot.
#
# Rules
#
# Age ≥ 18 → Eligible
#
# Age < 18 → Not Eligible
#
# Real-Time Use
#
# Hospital appointment systems
#
# Healthcare portals
#
# Hint
#
# Use function
#
# Use condition checks
#
# Expected Output Format
#
# Patient Age: 21
#
# Eligibility Status: Eligible

# %%
#function to check wh'ether a patient is eligible for an appointment slot.
def appointment_eligibility_checker(age):
  print(f"Patient Age: {age}")
  if age >= 18:
    print("Eligibility Status: Eligible")
  else:
    print("Eligibility Status: Not Eligible")

# %%
patients_age=[19,72,10,15,34,16,26,21,18,20,11]
for i in patients_age:
  appointment_eligibility_checker(i)
# Out:
# Patient Age: 19
# Eligibility Status: Eligible
# Patient Age: 72
# Eligibility Status: Eligible
# Patient Age: 10
# Eligibility Status: Not Eligible
# Patient Age: 15
# Eligibility Status: Not Eligible
# Patient Age: 34
# Eligibility Status: Eligible
# Patient Age: 16
# Eligibility Status: Not Eligible
# Patient Age: 26
# Eligibility Status: Eligible
# Patient Age: 21
# Eligibility Status: Eligible
# Patient Age: 18
# Eligibility Status: Eligible
# Patient Age: 20
# Eligibility Status: Eligible
# Patient Age: 11
# Eligibility Status: Not Eligible

# %% [markdown]
# # Problem 6: Agriculture – Premium Crop Price Filter
# Problem Statement
#
# Create a function that filters crop prices above a premium threshold.
#
# Rules
#
# Price > ₹2000 → Premium Crop
#
# Else → Regular Crop
#
# Real-Time Use
#
# Market analytics
#
# Export pricing systems
#
# Hint
#
# Use function
#
# Use list filtering logic
#
# Expected Output Format
#
# Premium Crops: [2500, 3200]

# %%
#function that filters crop prices above a premium threshold.
def filter_crop_prices(crop_prices):
  premium_crop_prices = [i for i in crop_prices if i > 2000]
  print("Premium Crops:",premium_crop_prices)

# %%
crop_prices=[1500,1000,1280,2786,9088,6432,1234,652,1321,5467]
filter_crop_prices(crop_prices)
# Out:
# Premium Crops: [2786, 9088, 6432, 5467]

# %% [markdown]
# # Problem 7: System Monitoring – Application Health Checker
# Problem Statement
#
# Create a function to evaluate application health based on error count.
#
# Rules
#
# Errors = 0 → Healthy
#
# Errors ≤ 5 → Minor Issues
#
# Errors > 5 → Critical Issues
#
# Real-Time Use
#
# System monitoring tools
#
# IT operations dashboards
#
# Hint
#
# Use function
#
# Use conditional statements
#
# Expected Output Format
#
# Error Count: 7
#
# System Status: Critical Issues

# %%
#function to evaluate application health based on error count.
def evaluate_health(error_count):
  print(f"Error Count: {error_count}")
  if error_count == 0:
    print("System Status: Healthy")
  elif error_count <=5:
    print("System Status: Minor Issues")
  else:
    print("System Status: Critical Issues")

# %%
errors=[0,4,8,2,9,3,5,7,6,10]
for i in errors:
  evaluate_health(i)
# Out:
# Error Count: 0
# System Status: Healthy
# Error Count: 4
# System Status: Minor Issues
# Error Count: 8
# System Status: Critical Issues
# Error Count: 2
# System Status: Minor Issues
# Error Count: 9
# System Status: Critical Issues
# Error Count: 3
# System Status: Minor Issues
# Error Count: 5
# System Status: Minor Issues
# Error Count: 7
# System Status: Critical Issues
# Error Count: 6
# System Status: Critical Issues
# Error Count: 10
# System Status: Critical Issues

# %% [markdown]
# # Problem 8: Banking – Daily Transaction Limit Checker
# Problem Statement
#
# Create a function to validate daily transaction amount.
#
# Rules
#
# Daily limit = ₹50,000
#
# Amount within limit → Approved
#
# Amount exceeds limit → Rejected
#
# Real-Time Use
#
# Banking systems
#
# Fraud prevention systems
#
# Hint
#
# Use function
#
# Use conditional logic
#
# Expected Output Format
#
# Transaction Amount: 60000
#
# Transaction Status: Rejected

# %%
# function to validate daily transaction amount.
def validate_transaction_amount(amount):
  daily_limit = 50000
  print("Transaction Amount:",amount)
  if amount <= daily_limit:
    print("Transaction Status: Approved")
  else:
    print("Transaction Status: Rejected")

# %%
amounts=[12000,34675,89000,78000,56000,23000,54890,200,160098,678000]

# %%
for i in amounts:
  validate_transaction_amount(i)
# Out:
# Transaction Amount: 12000
# Transaction Status: Approved
# Transaction Amount: 34675
# Transaction Status: Approved
# Transaction Amount: 89000
# Transaction Status: Rejected
# Transaction Amount: 78000
# Transaction Status: Rejected
# Transaction Amount: 56000
# Transaction Status: Rejected
# Transaction Amount: 23000
# Transaction Status: Approved
# Transaction Amount: 54890
# Transaction Status: Rejected
# Transaction Amount: 200
# Transaction Status: Approved
# Transaction Amount: 160098
# Transaction Status: Rejected
# Transaction Amount: 678000
# Transaction Status: Rejected

# %% [markdown]
# # Problem 9: E-Learning – Student Attendance Eligibility System
# Problem Statement
#
# Create a function to calculate attendance percentage and check exam eligibility.
#
# Rules
#
# Attendance ≥ 75% → Eligible
#
# Attendance < 75% → Not Eligible
#
# Real-Time Use
#
# Learning management systems
#
# Internship tracking platforms
#
# Hint
#
# Use function
#
# Use list and loop
#
# Expected Output Format
#
# Attendance Percentage: 80.0
#
# Exam Eligibility: Eligible

# %%
#function to calculate attendance percentage and check exam eligibility.
def calculate_attendance_percentage(attendance_list):
  total_days = len(attendance_list)
  present_days = attendance_list.count(1)
  attendance_percentage = (present_days / total_days) * 100
  print("Attendance Percentage:",attendance_percentage)
  if attendance_percentage >= 75:
    print("Exam Eligibility: Eligible")
  else:
    print("Exam Eligibility: Not Eligible")

# %%
attendance_list=[1,0,1,1,1,0,0,1,0,1,1,1,1,0]
calculate_attendance_percentage(attendance_list)
# Out:
# Attendance Percentage: 64.28571428571429
# Exam Eligibility: Not Eligible

# %% [markdown]
# # Problem 10: Smart Electricity Bill Analyzer
# Problem Statement
#
# You are building a smart electricity billing system for residential users.
#
# Create a function that calculates the electricity bill and classifies usage level based on units consumed.
#
# Billing Rules
#
# First 100 units → ₹3 per unit
#
# Next 100 units (101–200) → ₹5 per unit
#
# Above 200 units → ₹7 per unit
#
# Usage Classification
#
# Total bill < ₹500 → Low Usage
#
# ₹500 – ₹1500 → Moderate Usage
#
# ₹1500 → High Usage
#
# Real-Time Use
#
# Smart meter systems
#
# Electricity board billing software
#
# Energy consumption analytics
#
# Hint
#
# Use function to calculate bill
#
# Use conditional logic for slabs
#
# Use return values (bill and usage status)

# %%
#function that calculates the electricity bill
def calculate_electricity_bill(units):
  if units <=100:
    bill = units*3
  elif 100<units<=200:
    bill = units*5
  else:
    bill = units*7

  if bill < 500:
    usage_status = "Low Usage"
  elif 500<=bill<=1500:
    usage_status = "Moderate Usage"
  else:
    usage_status = "High Usage"

  return bill,usage_status

# %%
electricity_units=[100,120,29,156,206,36,98,189,299,304]
for i in electricity_units:
  bill,usage_status = calculate_electricity_bill(i)
  print(f"Units: {i}")
  print(f"Bill: {bill}")
  print(f"Usage Status: {usage_status}")
# Out:
# Units: 100
# Bill: 300
# Usage Status: Low Usage
# Units: 120
# Bill: 600
# Usage Status: Moderate Usage
# Units: 29
# Bill: 87
# Usage Status: Low Usage
# Units: 156
# Bill: 780
# Usage Status: Moderate Usage
# Units: 206
# Bill: 1442
# Usage Status: Moderate Usage
# Units: 36
# Bill: 108
# Usage Status: Low Usage
# Units: 98
# Bill: 294
# Usage Status: Low Usage
# Units: 189
# Bill: 945
# Usage Status: Moderate Usage
# Units: 299
# Bill: 2093
# Usage Status: High Usage
# Units: 304
# Bill: 2128
# Usage Status: High Usage
